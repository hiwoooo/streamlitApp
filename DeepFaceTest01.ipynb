# %%
# %pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\programdata\anaconda3\lib\site-packages (4.5.5.64)
# Requirement already satisfied: numpy>=1.17.3 in c:\programdata\anaconda3\lib\site-packages (from opencv-python) (1.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install deepface
# Out:
# Requirement already satisfied: deepface in c:\programdata\anaconda3\lib\site-packages (0.0.74)
# Requirement already satisfied: opencv-python>=3.4.4 in c:\programdata\anaconda3\lib\site-packages (from deepface) (4.5.5.64)
# Requirement already satisfied: Flask>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from deepface) (1.1.2)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\programdata\anaconda3\lib\site-packages (from deepface) (0.1.1)
# Requirement already satisfied: Pillow>=5.2.0 in c:\programdata\anaconda3\lib\site-packages (from deepface) (8.4.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\programdata\anaconda3\lib\site-packages (from deepface) (4.62.3)
# Requirement already satisfied: numpy>=1.14.0 in c:\programdata\anaconda3\lib\site-packages (from deepface) (1.20.3)
# Requirement already satisfied: keras>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from deepface) (2.8.0)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from deepface) (2.8.0)
# Requirement already satisfied: pandas>=0.23.4 in c:\programdata\anaconda3\lib\site-packages (from deepface) (1.3.4)
# Requirement already satisfied: gdown>=3.10.1 in c:\programdata\anaconda3\lib\site-packages (from deepface) (4.4.0)
# Requirement already satisfied: retina-face>=0.0.1 in c:\programdata\anaconda3\lib\site-packages (from deepface) (0.0.10)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\programdata\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\programdata\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.0.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\programdata\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.0.1)
# Requirement already satisfied: click>=5.1 in c:\programdata\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (8.0.3)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=5.1->Flask>=1.1.2->deepface) (0.4.4)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (3.3.1)
# Requirement already satisfied: requests[socks] in c:\programdata\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (2.26.0)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (4.10.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.1.2->deepface) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2021.3)
# Requirement already satisfied: gast>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.5.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.44.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.24.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.8.0.dev2021122109)
# Requirement already satisfied: termcolor>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.2.1)
# Requirement already satisfied: absl-py>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.10.0.2)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (58.0.4)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.12.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (13.0.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.8.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.19.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: flatbuffers>=1.12 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.37.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (2.6.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (3.3.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (5.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\programdata\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=1.9.0->deepface) (3.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.2.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from deepface import DeepFace

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# %%
# 1. 비디오 객체 생성
video = cv2.VideoCapture(0) 
# 2. 변수
a = 0
# 3. While loop
while True:
    a = a + 1
    # 4.프레임 객체 생성
    check, frame = video.read()
    # 그레이스케일로 변환
    #gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    # 5.프레임 보이기
    cv2.imshow("Capturing",frame)
    # 6.이미지 캡처
    key = cv2.waitKey(1)
    if key == ord('q'):
        break
# 7. 이미지 저장
showPic = cv2.imwrite("photo.jpg",frame)
print(showPic)
# 8. 카메라 종료
video.release()
cv2.destroyAllWindows
# Out:
# True
# <function destroyAllWindows>

# %%
img = cv2.imread('photo.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.39it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 0.0002862242922819773,
#   'disgust': 8.763519427885372e-09,
#   'fear': 0.28829841120373145,
#   'happy': 99.67746134727733,
#   'sad': 0.01634085687494807,
#   'surprise': 0.0018026745567841858,
#   'neutral': 0.015812098420177213},
#  'dominant_emotion': 'happy',
#  'region': {'x': 231, 'y': 226, 'w': 203, 'h': 203},
#  'age': 32,
#  'gender': 'Man',
#  'race': {'asian': 95.71178555488586,
#   'indian': 0.14380281791090965,
#   'black': 0.0077816235716454685,
#   'white': 0.9037419222295284,
#   'middle eastern': 0.01046649704221636,
#   'latino hispanic': 3.2224174588918686},
#  'dominant_race': 'asian'}
